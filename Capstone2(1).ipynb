# %%
#run the notebook to view results op-fnx
import pandas as pd

# %%
pip install lxml html5lib beautifulsoup4

# %%
newdata=pd.read_html('https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M')
ndt=newdata[0]

# %%
newdata1=ndt[['Postal Code','Neighborhood','Borough']]

# %%
newdata1

# %%
newdata2 = newdata1[newdata1['Borough'] != 'Not assigned'].reset_index(drop=True)
newdata2.head()

# %%
newdata2.shape

# %%
newdata2.groupby('Postal Code')
newdata2.head()

# %% [markdown]
# For the first problem, the table was extracted from the website and then, the records with not assigned borough were omitted. The records with common postal code were grouped and there were no records with a not assigned neighborhood and an assigned borough.
#
# Assumptions: Records remain consistent while normalization(no data are anomalies)

# %%
df=pd.read_csv("https://cocl.us/Geospatial_data")

# %%
df

# %%
df1=df.merge(newdata2)
df1.head()

# %%
df1.groupby('Borough').count()

# %%
toronto_grouped = df1.groupby('Neighborhood').mean().reset_index()
toronto_grouped

# %%
import random # library for random number generation
import numpy as np # library for vectorized computation
import pandas as pd # library to process data as dataframes

import matplotlib.pyplot as plt # plotting library
# backend for rendering plots within the browser
# %matplotlib inline 

from sklearn.cluster import KMeans 
from sklearn.datasets.samples_generator import make_blobs

# %%
import folium

# %%
import matplotlib.cm as cm
import matplotlib.colors as colors

# %%
# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim

# %%
address = 'Toronto'

geolocator = Nominatim(user_agent="on_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude

# %%
toronto_grouped.insert(0, 'Cluster Labels', kmeans.labels_)

# %%
toronto_grouped1=toronto_grouped.merge(df)

# %%
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(toronto_grouped['Latitude'], toronto_grouped['Longitude'], toronto_grouped['Neighborhood'],toronto_grouped['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters

# %%
toronto_grouped.loc[toronto_grouped['Cluster Labels'] == 0, toronto_grouped.columns[[1] + list(range(5, toronto_grouped.shape[1]))]]

# %%
toronto_grouped.loc[toronto_grouped['Cluster Labels'] == 1, toronto_grouped.columns[[1] + list(range(5, toronto_grouped.shape[1]))]]

# %%
toronto_grouped.loc[toronto_grouped['Cluster Labels'] == 2, toronto_grouped.columns[[1] + list(range(5, toronto_grouped.shape[1]))]]

# %%
toronto_grouped.loc[toronto_grouped['Cluster Labels'] == 3, toronto_grouped.columns[[1] + list(range(5, toronto_grouped.shape[1]))]]

# %%
toronto_grouped.loc[toronto_grouped['Cluster Labels'] == 4, toronto_grouped.columns[[1] + list(range(5, toronto_grouped.shape[1]))]]
